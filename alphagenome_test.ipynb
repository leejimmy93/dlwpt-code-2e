# %%
# !pip install alphagenome-pytorch
# Out:
# Collecting alphagenome-pytorch
#   Downloading alphagenome_pytorch-0.3.0-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from alphagenome-pytorch) (1.26.4)
# Requirement already satisfied: torch>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from alphagenome-pytorch) (2.6.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch>=2.0.0->alphagenome-pytorch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch>=2.0.0->alphagenome-pytorch) (4.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch>=2.0.0->alphagenome-pytorch) (82.0.0)
# Requirement already satisfied: sympy!=1.13.2,>=1.13.1 in /opt/conda/lib/python3.12/site-packages (from torch>=2.0.0->alphagenome-pytorch) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch>=2.0.0->alphagenome-pytorch) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=2.0.0->alphagenome-pytorch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch>=2.0.0->alphagenome-pytorch) (2024.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy!=1.13.2,>=1.13.1->torch>=2.0.0->alphagenome-pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->alphagenome-pytorch) (3.0.3)
# Downloading alphagenome_pytorch-0.3.0-py3-none-any.whl (169 kB)
# Installing collected packages: alphagenome-pytorch
# Successfully installed alphagenome-pytorch-0.3.0

# %%
from alphagenome_pytorch import AlphaGenome
from alphagenome_pytorch.utils.sequence import sequence_to_onehot_tensor
from huggingface_hub import hf_hub_download
import pyfaidx

hf_hub_download(
  "gtca/alphagenome_pytorch",
  "model_all_folds.safetensors",
  local_dir="."
)

model = AlphaGenome.from_pretrained("model_all_folds.safetensors")

with pyfaidx.Fasta("hg38.fa") as genome:
    sequence = str(genome["chr1"][1_000_000:1_131_072])

dna_onehot = sequence_to_onehot_tensor(sequence).unsqueeze(0)

preds = model.predict(dna_onehot, organism_index=0)  # 0=human, 1=mouse

# Access predictions (batch, sequence, tracks) by head name and resolution:
# - preds['atac'][1]: 1bp resolution, shape (1, 131072, 256)
# - preds['atac'][128]: 128bp resolution, shape (1, 1024, 256)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 from alphagenome_pytorch.utils.sequence import sequence_to_onehot_tensor
#       3 from huggingface_hub import hf_hub_download
# ----> 4 import pyfaidx
#       6 hf_hub_download(
#       7   "gtca/alphagenome_pytorch",
#       8   "model_all_folds.safetensors",
#       9   local_dir="."
#      10 )
#      12 model = AlphaGenome.from_pretrained("model_all_folds.safetensors")
#
# ModuleNotFoundError: No module named 'pyfaidx'
